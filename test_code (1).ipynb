# %%
import pandas as pd

# %%
spr_full = pd.read_excel("sprFull.xlsx")

# %%
spr_full.columns

spr_full["distance"] = 50

spr_full.rename(columns={'HS_50Free': 'time', 'diff50': 'tdiff'}, inplace=True)

spr_full.head()
# Out:
#              Swimmer   time        Hometown  College.Time  Elevation  \
# 0        Ailey Ruger  24.78     Boulder, CO         24.55       5328
# 1      Andrea Basile  23.92  Oconomowoc, WI         24.14        869
# 2      Breann Fuller  25.03   Brighton, USA         23.00       5000
# 3        Carmen Mand  23.44    Portland, OR         23.19         39
# 4  Christina Bassani  25.43      Parker, CO         24.17       5869
#
#         Altitude School  tdiff  distance
# 0  Above 5000 ft    CSU  -0.23        50
# 1  Below 5000 ft    CSU   0.22        50
# 2  Above 5000 ft    CSU  -2.03        50
# 3  Below 5000 ft    CSU  -0.25        50
# 4  Above 5000 ft    CSU  -1.26        50

# %%
import seaborn as sns

sns.pairplot(spr_full[["time", "College.Time", "tdiff"]])
